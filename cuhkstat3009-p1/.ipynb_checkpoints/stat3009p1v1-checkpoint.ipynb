# %%
###############################################
# CUHK STAT3009 Recommender Systems Project 1 #
###############################################

import numpy as np
import pandas as pd

dtrain = pd.read_csv('train.csv', usecols=['user_id', 'item_id', 'rating'])
dtest = pd.read_csv('test.csv', usecols=['user_id', 'item_id'])
sub = pd.read_csv('sample_submission.csv')

train_pair = dtrain[["user_id", "item_id"]].values
train_rating = np.array(dtrain["rating"])
test_pair = dtest[["user_id", "item_id"]].values

n_user = max(train_pair[:,0]) + 1
print('number of users: %d' %n_user)
n_item = max(train_pair[:,1]) + 1
print('number of items: %d' %n_item)

def rmse(true, pred):
	return np.sqrt(np.mean((pred - true)**2))
# Out:
# number of users: 500
# number of items: 1000

# %%
#EDA for the users and items
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

ax1.hist(dtrain["user_id"], 25, density=True, facecolor='b', alpha=0.75)
ax1.set(xlim = [min(dtrain["user_id"]), max(dtrain["user_id"])])
ax1.grid(True)

ax2.hist(dtrain["item_id"], 25, density=True, facecolor='b', alpha=0.75)
ax2.set(xlim = [min(dtrain["item_id"]), max(dtrain["item_id"])])
ax2.grid(True)

# %%
#EDA for the ratings
plt.hist(dtrain["rating"], len(dtrain["rating"].unique()), density=True, facecolor='b', alpha=0.75)
plt.xlim(min(dtrain["rating"]), max(dtrain["rating"]))
plt.grid(True)

# %%
freq_item = []
freq_user = []

index_item = [np.where(train_pair[:,1] == i)[0] for i in range(n_item)]
index_user = [np.where(train_pair[:,0] == u)[0] for u in range(n_user)]

for i in range(n_item):
    freq_item.append(len(index_item[i]))
    
for i in range(n_user):
    freq_user.append(len(index_user[i]))

# %%
#EDA for the scatter plot of ID vs Freq
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

ax1.scatter(range(n_item), freq_item,  facecolor='b', alpha=0.75)
ax1.grid(True)

ax2.scatter(range(n_user), freq_user, facecolor='b', alpha=0.75)
ax2.grid(True)

# %%
# save indices for all users/items
index_item = [np.where(train_pair[:,1] == i)[0] for i in range(n_item)]
index_user = [np.where(train_pair[:,0] == u)[0] for u in range(n_user)]

# %%
class MF(object):

    def __init__(self, n_user, n_item, lam=.001, K=10, iterNum=1000, GDiterNum=10, tol=1e-4):
        self.P = np.random.randn(n_user, K)
        self.Q = np.random.randn(n_item, K)
        self.n_user = n_user
        self.n_item = n_item
        self.lam = lam
        self.K = K
        self.iterNum = iterNum
        self.GDiterNum = GDiterNum
        self.tol = tol

    def fit(self, train_pair, train_rating, learning_rate=0.0001):
        diff, tol = 1., self.tol
        n_user, n_item, n_obs = self.n_user, self.n_item, len(train_pair)
        K, iterNum, lam = self.K, self.iterNum, self.lam
        ## store user/item index set
        self.index_item = [np.where(train_pair[:,1] == i)[0] for i in range(n_item)]
        self.index_user = [np.where(train_pair[:,0] == u)[0] for u in range(n_user)]
        print('Fitting Reg-MF: K: %d, lam: %.5f' %(K, lam))
        for i in range(iterNum):
            ## item update
            obj_old = self.obj(test_pair=train_pair, test_rating=train_rating)
            for item_id in range(n_item):
                index_item_tmp = self.index_item[item_id]
                if len(index_item_tmp) == 0:
                    self.Q[item_id,:] = 0.
                    continue
                train_pair_tmp, train_rating_tmp = train_pair[index_item_tmp], train_rating[index_item_tmp]
                ## GD block
                for h in range(self.GDiterNum):
                  ## compute res on the current model
                  err_tmp = train_rating_tmp - self.predict(test_pair=train_pair_tmp)
                  sum_pu = np.sum(self.P[train_pair_tmp[:,0]] * err_tmp[:,np.newaxis], 0) / n_obs
                  ## GD updates for Q
                  self.Q[item_id] = self.Q[item_id] + 2*learning_rate*sum_pu - 2*learning_rate*lam*self.Q[item_id]
                
            for user_id in range(n_user):
                index_user_tmp = self.index_user[user_id]
                if len(index_user_tmp) == 0:
                    self.P[user_id,:] = 0.
                    continue
                train_pair_tmp, train_rating_tmp = train_pair[index_user_tmp], train_rating[index_user_tmp]
                for h in range(self.GDiterNum):
                  ## compute res on the current model
                  err_tmp = train_rating_tmp - self.predict(test_pair=train_pair_tmp)
                  sum_qi = np.sum(self.Q[train_pair_tmp[:,1]] * err_tmp[:,np.newaxis], 0) / n_obs
                  ## GD updates for Q
                  self.P[user_id] = self.P[user_id] + 2*learning_rate*sum_qi - 2*learning_rate*lam*self.P[user_id]

            # compute the new rmse score
            obj_new = self.obj(test_pair=train_pair, test_rating=train_rating)
            rmse_new = self.rmse(test_pair=train_pair, test_rating=train_rating)
            diff = - obj_new + obj_old
            print("Reg-MF: GD - ite: %d; diff: %.3f; Obj: %.3f; RMSE: %.3f" %(i, diff, obj_new, rmse_new))
            if (diff < tol):
                break

    def predict(self, test_pair):
        # predict ratings for user-item pairs
        pred_rating = [np.dot(self.P[line[0]], self.Q[line[1]]) for line in test_pair]
        return np.array(pred_rating)

    def obj(self, test_pair, test_rating):
        return (self.rmse(test_pair, test_rating))**2 + self.lam*np.sum(self.P**2) + self.lam*np.sum(self.Q**2)
    
    def rmse(self, test_pair, test_rating):
        # report the rmse for the fitted `MF`
        pred_rating = self.predict(test_pair=test_pair)
        return np.sqrt( np.mean( (pred_rating - test_rating)**2) )

# %%
# baseline methods
class glb_mean(object):
	def __init__(self):
		self.glb_mean = 0
	
	def fit(self, train_ratings):
		self.glb_mean = np.mean(train_ratings)
	
	def predict(self, test_pair):
		pred = np.ones(len(test_pair))
		pred = pred*self.glb_mean
		return pred

class user_mean(object):
	def __init__(self, n_user):
		self.n_user = n_user
		self.glb_mean = 0.
		self.user_mean = np.zeros(n_user)
	
	def fit(self, train_pair, train_ratings):
		self.glb_mean = train_ratings.mean()
		for u in range(self.n_user):
			ind_train = np.where(train_pair[:,0] == u)[0]
			if len(ind_train) == 0:
				self.user_mean[u] = self.glb_mean
			else:
				self.user_mean[u] = train_ratings[ind_train].mean()
	
	def predict(self, test_pair):
		pred = np.ones(len(test_pair))*self.glb_mean
		j = 0
		for row in test_pair:
			user_tmp, item_tmp = row[0], row[1]
			pred[j] = self.user_mean[user_tmp]
			j = j + 1
		return pred

class item_mean(object):
	def __init__(self, n_item):
		self.n_item = n_item
		self.glb_mean = 0.
		self.item_mean = np.zeros(n_item)
	
	def fit(self, train_pair, train_ratings):
		self.glb_mean = train_ratings.mean()
		for i in range(self.n_item):
			ind_train = np.where(train_pair[:,1] == i)[0]
			if len(ind_train) == 0:
				self.item_mean[i] = self.glb_mean
			else:
				self.item_mean[i] = train_ratings[ind_train].mean()
	
	def predict(self, test_pair):
		pred = np.ones(len(test_pair))*self.glb_mean
		j = 0
		for row in test_pair:
			user_tmp, item_tmp = row[0], row[1]
			pred[j] = self.item_mean[item_tmp]
			j = j + 1
		return pred

# %%
from sklearn.model_selection import KFold
import itertools
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

class MF_CV(object):

	def __init__(self, n_user, n_item, cv=5,
				lams=[.000001,.0001,.001,.01], 
				Ks=[3,5,10,20], 
				iterNum=10, tol=1e-4):
		self.n_user = n_user
		self.n_item = n_item
		self.cv = cv
		self.lams = lams
		self.Ks = Ks
		self.iterNum = iterNum
		self.tol = tol
		self.best_model = {}
		self.cv_result = {'K': [], 'lam': [], 'train_rmse': [], 'valid_rmse': []}

	def grid_search(self, train_pair, train_rating):
		## generate all comb of `K` and `lam`
		kf = KFold(n_splits=self.cv, shuffle=True)
		for (K,lam) in itertools.product(self.Ks, self.lams):
			train_rmse_tmp, valid_rmse_tmp = 0., 0.
			for train_index, valid_index in kf.split(train_pair):
				# produce training/validation sets
				train_pair_cv, train_rating_cv = train_pair[train_index], train_rating[train_index]
				valid_pair_cv, valid_rating_cv = train_pair[valid_index], train_rating[valid_index]
				# fit the model based on CV data
				model_tmp = MF(self.n_user, self.n_item, K=K, lam=lam)
				model_tmp.fit(train_pair=train_pair_cv, train_rating=train_rating_cv, learning_rate=1)
				train_rmse_tmp_cv = model_tmp.rmse(test_pair=train_pair_cv, test_rating=train_rating_cv)
				valid_rmse_tmp_cv = model_tmp.rmse(test_pair=valid_pair_cv, test_rating=valid_rating_cv)
				train_rmse_tmp = train_rmse_tmp + train_rmse_tmp_cv / self.cv
				valid_rmse_tmp = valid_rmse_tmp + valid_rmse_tmp_cv / self.cv
				print('%d-Fold CV for K: %d; lam: %f: train_rmse: %f, valid_rmse: %f' 
						%(self.cv, K, lam, train_rmse_tmp_cv, valid_rmse_tmp_cv))
			self.cv_result['K'].append(K)
			self.cv_result['lam'].append(lam)
			self.cv_result['train_rmse'].append(train_rmse_tmp)
			self.cv_result['valid_rmse'].append(valid_rmse_tmp)
		self.cv_result = pd.DataFrame.from_dict(self.cv_result)
		best_ind = self.cv_result['valid_rmse'].argmin()
		self.best_model = self.cv_result.loc[best_ind]
	
	def plot_grid(self, data_source='valid'):
		sns.set_theme()
		if data_source == 'train':
			cv_pivot = self.cv_result.pivot("K", "lam", "train_rmse")
		elif data_source == 'valid':
			cv_pivot = self.cv_result.pivot("K", "lam", "valid_rmse")
		else:
			raise ValueError('data_source must be train or valid!')
		sns.heatmap(cv_pivot, annot=True, fmt=".3f", linewidths=.5, cmap="YlGnBu")
		plt.show()

# %%
#Set grids
folds = 5
Ks, lams = np.arange(1, 51, 1), 10**np.arange(-3, 3, .5)

# %%
## Baseline `glb mean based and user fitted` + MF
# glb mean
glb_ave = glb_mean()
glb_ave.fit(train_rating)
pred_rating = glb_ave.predict(test_pair)

# user_mean
train_rating_cm = train_rating - glb_ave.predict(train_pair)
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - user_ave.predict(train_pair)
pred_rating = pred_rating + user_ave.predict(test_pair)

#Grid Search
shiing_cv = MF_CV(n_user, n_item, cv=folds, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=MF(n_user, n_item, K=best_K, lam=best_lam, learning_rate=1)
shiing.fit(train_pair, train_rating_res)
pred_rating = pred_rating + shiing.predict(test_pair)
# Out:
# Fitting Reg-MF: K: 1, lam: 0.00100
# Reg-MF: GD - ite: 0; diff: 2.128; Obj: 11.824; RMSE: 3.333
# Reg-MF: GD - ite: 1; diff: 0.450; Obj: 11.374; RMSE: 3.291
# Reg-MF: GD - ite: 2; diff: 0.241; Obj: 11.133; RMSE: 3.259
# Reg-MF: GD - ite: 3; diff: 0.205; Obj: 10.928; RMSE: 3.222
# Reg-MF: GD - ite: 4; diff: 0.235; Obj: 10.693; RMSE: 3.173
# Reg-MF: GD - ite: 5; diff: 0.338; Obj: 10.355; RMSE: 3.098
# Reg-MF: GD - ite: 6; diff: 0.543; Obj: 9.812; RMSE: 2.978
# Reg-MF: GD - ite: 7; diff: 0.836; Obj: 8.976; RMSE: 2.786
# Reg-MF: GD - ite: 8; diff: 1.067; Obj: 7.909; RMSE: 2.518
# Reg-MF: GD - ite: 9; diff: 0.983; Obj: 6.926; RMSE: 2.230
# Reg-MF: GD - ite: 10; diff: 0.591; Obj: 6.335; RMSE: 2.017
# Reg-MF: GD - ite: 11; diff: 0.270; Obj: 6.066; RMSE: 1.893
# Reg-MF: GD - ite: 12; diff: 0.118; Obj: 5.947; RMSE: 1.825
# Reg-MF: GD - ite: 13; diff: 0.055; Obj: 5.892; RMSE: 1.785
# Reg-MF: GD - ite: 14; diff: 0.028; Obj: 5.864; RMSE: 1.760
# Reg-MF: GD - ite: 15; diff: 0.015; Obj: 5.850; RMSE: 1.744
# Reg-MF: GD - ite: 16; diff: 0.008; Obj: 5.841; RMSE: 1.734
# Reg-MF: GD - ite: 17; diff: 0.005; Obj: 5.836; RMSE: 1.727
# Reg-MF: GD - ite: 18; diff: 0.003; Obj: 5.834; RMSE: 1.722
# Reg-MF: GD - ite: 19; diff: 0.002; Obj: 5.832; RMSE: 1.718
# Reg-MF: GD - ite: 20; diff: 0.001; Obj: 5.831; RMSE: 1.716
# Reg-MF: GD - ite: 21; diff: 0.001; Obj: 5.830; RMSE: 1.714
# Reg-MF: GD - ite: 22; diff: 0.000; Obj: 5.830; RMSE: 1.713
# Reg-MF: GD - ite: 23; diff: 0.000; Obj: 5.830; RMSE: 1.712
# Reg-MF: GD - ite: 24; diff: 0.000; Obj: 5.830; RMSE: 1.711
# Reg-MF: GD - ite: 25; diff: 0.000; Obj: 5.830; RMSE: 1.711
# 5-Fold CV for K: 1; lam: 0.001000: train_rmse: 1.710551, valid_rmse: 1.995736
# Fitting Reg-MF: K: 1, lam: 0.00100
# Reg-MF: GD - ite: 0; diff: 1.774; Obj: 11.992; RMSE: 3.356
# Reg-MF: GD - ite: 1; diff: 0.434; Obj: 11.558; RMSE: 3.314
# Reg-MF: GD - ite: 2; diff: 0.321; Obj: 11.237; RMSE: 3.268
# Reg-MF: GD - ite: 3; diff: 0.479; Obj: 10.759; RMSE: 3.178
# Reg-MF: GD - ite: 4; diff: 0.909; Obj: 9.850; RMSE: 2.990
# Reg-MF: GD - ite: 5; diff: 1.391; Obj: 8.459; RMSE: 2.668
# Reg-MF: GD - ite: 6; diff: 1.286; Obj: 7.173; RMSE: 2.309
# Reg-MF: GD - ite: 7; diff: 0.727; Obj: 6.446; RMSE: 2.054
# Reg-MF: GD - ite: 8; diff: 0.332; Obj: 6.114; RMSE: 1.906
# Reg-MF: GD - ite: 9; diff: 0.148; Obj: 5.966; RMSE: 1.824
# Reg-MF: GD - ite: 10; diff: 0.067; Obj: 5.899; RMSE: 1.778
# Reg-MF: GD - ite: 11; diff: 0.031; Obj: 5.868; RMSE: 1.751
# Reg-MF: GD - ite: 12; diff: 0.016; Obj: 5.852; RMSE: 1.734
# Reg-MF: GD - ite: 13; diff: 0.009; Obj: 5.843; RMSE: 1.723
# Reg-MF: GD - ite: 14; diff: 0.005; Obj: 5.837; RMSE: 1.716
# Reg-MF: GD - ite: 15; diff: 0.003; Obj: 5.834; RMSE: 1.710
# Reg-MF: GD - ite: 16; diff: 0.002; Obj: 5.832; RMSE: 1.707
# Reg-MF: GD - ite: 17; diff: 0.001; Obj: 5.830; RMSE: 1.704
# Reg-MF: GD - ite: 18; diff: 0.001; Obj: 5.830; RMSE: 1.702
# Reg-MF: GD - ite: 19; diff: 0.001; Obj: 5.829; RMSE: 1.700
# Reg-MF: GD - ite: 20; diff: 0.000; Obj: 5.829; RMSE: 1.699
# Reg-MF: GD - ite: 21; diff: 0.000; Obj: 5.829; RMSE: 1.698
# Reg-MF: GD - ite: 22; diff: 0.000; Obj: 5.828; RMSE: 1.698
# Reg-MF: GD - ite: 23; diff: 0.000; Obj: 5.828; RMSE: 1.697
# 5-Fold CV for K: 1; lam: 0.001000: train_rmse: 1.697174, valid_rmse: 2.005543
# Fitting Reg-MF: K: 1, lam: 0.00100
# Reg-MF: GD - ite: 0; diff: 1.942; Obj: 12.081; RMSE: 3.361
# Reg-MF: GD - ite: 1; diff: 0.462; Obj: 11.619; RMSE: 3.320
# Reg-MF: GD - ite: 2; diff: 0.299; Obj: 11.319; RMSE: 3.281
# Reg-MF: GD - ite: 3; diff: 0.365; Obj: 10.954; RMSE: 3.215
# Reg-MF: GD - ite: 4; diff: 0.617; Obj: 10.337; RMSE: 3.089
# Reg-MF: GD - ite: 5; diff: 1.039; Obj: 9.298; RMSE: 2.861
# Reg-MF: GD - ite: 6; diff: 1.346; Obj: 7.952; RMSE: 2.529
# Reg-MF: GD - ite: 7; diff: 1.095; Obj: 6.857; RMSE: 2.202
# Reg-MF: GD - ite: 8; diff: 0.564; Obj: 6.293; RMSE: 1.986
# Reg-MF: GD - ite: 9; diff: 0.240; Obj: 6.054; RMSE: 1.868
# Reg-MF: GD - ite: 10; diff: 0.103; Obj: 5.951; RMSE: 1.804
# Reg-MF: GD - ite: 11; diff: 0.047; Obj: 5.904; RMSE: 1.767
# Reg-MF: GD - ite: 12; diff: 0.023; Obj: 5.881; RMSE: 1.745
# Reg-MF: GD - ite: 13; diff: 0.012; Obj: 5.869; RMSE: 1.730
# Reg-MF: GD - ite: 14; diff: 0.007; Obj: 5.862; RMSE: 1.721
# Reg-MF: GD - ite: 15; diff: 0.004; Obj: 5.859; RMSE: 1.715
# Reg-MF: GD - ite: 16; diff: 0.002; Obj: 5.857; RMSE: 1.710
# Reg-MF: GD - ite: 17; diff: 0.001; Obj: 5.855; RMSE: 1.707
# Reg-MF: GD - ite: 18; diff: 0.001; Obj: 5.855; RMSE: 1.705
# Reg-MF: GD - ite: 19; diff: 0.001; Obj: 5.854; RMSE: 1.704
# Reg-MF: GD - ite: 20; diff: 0.000; Obj: 5.854; RMSE: 1.703
# Reg-MF: GD - ite: 21; diff: 0.000; Obj: 5.853; RMSE: 1.702
# Reg-MF: GD - ite: 22; diff: 0.000; Obj: 5.853; RMSE: 1.701
# Reg-MF: GD - ite: 23; diff: 0.000; Obj: 5.853; RMSE: 1.701
# Reg-MF: GD - ite: 24; diff: 0.000; Obj: 5.853; RMSE: 1.700
# 5-Fold CV for K: 1; lam: 0.001000: train_rmse: 1.700338, valid_rmse: 1.932946
# Fitting Reg-MF: K: 1, lam: 0.00100
# Reg-MF: GD - ite: 0; diff: 1.794; Obj: 11.945; RMSE: 3.345
# Reg-MF: GD - ite: 1; diff: 0.452; Obj: 11.493; RMSE: 3.301
# Reg-MF: GD - ite: 2; diff: 0.323; Obj: 11.170; RMSE: 3.255
# Reg-MF: GD - ite: 3; diff: 0.445; Obj: 10.725; RMSE: 3.172
# Reg-MF: GD - ite: 4; diff: 0.818; Obj: 9.907; RMSE: 3.003
# Reg-MF: GD - ite: 5; diff: 1.324; Obj: 8.584; RMSE: 2.700
# Reg-MF: GD - ite: 6; diff: 1.337; Obj: 7.246; RMSE: 2.336
# Reg-MF: GD - ite: 7; diff: 0.779; Obj: 6.467; RMSE: 2.066
# Reg-MF: GD - ite: 8; diff: 0.344; Obj: 6.123; RMSE: 1.913
# Reg-MF: GD - ite: 9; diff: 0.151; Obj: 5.971; RMSE: 1.827
# Reg-MF: GD - ite: 10; diff: 0.070; Obj: 5.901; RMSE: 1.778
# Reg-MF: GD - ite: 11; diff: 0.035; Obj: 5.866; RMSE: 1.747
# Reg-MF: GD - ite: 12; diff: 0.018; Obj: 5.849; RMSE: 1.728
# Reg-MF: GD - ite: 13; diff: 0.009; Obj: 5.840; RMSE: 1.716
# Reg-MF: GD - ite: 14; diff: 0.005; Obj: 5.835; RMSE: 1.708
# Reg-MF: GD - ite: 15; diff: 0.003; Obj: 5.832; RMSE: 1.703
# Reg-MF: GD - ite: 16; diff: 0.002; Obj: 5.830; RMSE: 1.699
# Reg-MF: GD - ite: 17; diff: 0.001; Obj: 5.829; RMSE: 1.697
# Reg-MF: GD - ite: 18; diff: 0.001; Obj: 5.829; RMSE: 1.695
# Reg-MF: GD - ite: 19; diff: 0.000; Obj: 5.828; RMSE: 1.694
# Reg-MF: GD - ite: 20; diff: 0.000; Obj: 5.828; RMSE: 1.693
# Reg-MF: GD - ite: 21; diff: 0.000; Obj: 5.828; RMSE: 1.692
# Reg-MF: GD - ite: 22; diff: 0.000; Obj: 5.828; RMSE: 1.692
# Reg-MF: GD - ite: 23; diff: 0.000; Obj: 5.828; RMSE: 1.691
# 5-Fold CV for K: 1; lam: 0.001000: train_rmse: 1.691306, valid_rmse: 1.962803
# Fitting Reg-MF: K: 1, lam: 0.00100
# Reg-MF: GD - ite: 0; diff: 1.883; Obj: 11.957; RMSE: 3.351
# Reg-MF: GD - ite: 1; diff: 0.511; Obj: 11.445; RMSE: 3.296
# Reg-MF: GD - ite: 2; diff: 0.473; Obj: 10.972; RMSE: 3.219
# Reg-MF: GD - ite: 3; diff: 0.807; Obj: 10.165; RMSE: 3.060
# Reg-MF: GD - ite: 4; diff: 1.324; Obj: 8.841; RMSE: 2.764
# Reg-MF: GD - ite: 5; diff: 1.390; Obj: 7.451; RMSE: 2.396
# Reg-MF: GD - ite: 6; diff: 0.868; Obj: 6.583; RMSE: 2.108
# Reg-MF: GD - ite: 7; diff: 0.415; Obj: 6.168; RMSE: 1.936
# Reg-MF: GD - ite: 8; diff: 0.185; Obj: 5.983; RMSE: 1.839
# Reg-MF: GD - ite: 9; diff: 0.078; Obj: 5.905; RMSE: 1.785
# Reg-MF: GD - ite: 10; diff: 0.033; Obj: 5.872; RMSE: 1.755
# Reg-MF: GD - ite: 11; diff: 0.015; Obj: 5.857; RMSE: 1.737
# Reg-MF: GD - ite: 12; diff: 0.007; Obj: 5.849; RMSE: 1.726
# Reg-MF: GD - ite: 13; diff: 0.004; Obj: 5.845; RMSE: 1.719
# Reg-MF: GD - ite: 14; diff: 0.002; Obj: 5.843; RMSE: 1.714
# Reg-MF: GD - ite: 15; diff: 0.001; Obj: 5.842; RMSE: 1.711
# Reg-MF: GD - ite: 16; diff: 0.001; Obj: 5.842; RMSE: 1.708
# Reg-MF: GD - ite: 17; diff: 0.000; Obj: 5.841; RMSE: 1.707
# Reg-MF: GD - ite: 18; diff: 0.000; Obj: 5.841; RMSE: 1.706
# Reg-MF: GD - ite: 19; diff: 0.000; Obj: 5.841; RMSE: 1.705
# Reg-MF: GD - ite: 20; diff: 0.000; Obj: 5.841; RMSE: 1.704
# 5-Fold CV for K: 1; lam: 0.001000: train_rmse: 1.704220, valid_rmse: 1.966154
# Fitting Reg-MF: K: 1, lam: 0.00316
# Reg-MF: GD - ite: 0; diff: 5.449; Obj: 12.282; RMSE: 3.350
# Reg-MF: GD - ite: 1; diff: 0.654; Obj: 11.628; RMSE: 3.351
# Reg-MF: GD - ite: 2; diff: 0.157; Obj: 11.471; RMSE: 3.356
# Reg-MF: GD - ite: 3; diff: 0.048; Obj: 11.423; RMSE: 3.360
# Reg-MF: GD - ite: 4; diff: 0.018; Obj: 11.405; RMSE: 3.362
# Reg-MF: GD - ite: 5; diff: 0.009; Obj: 11.395; RMSE: 3.363
# Reg-MF: GD - ite: 6; diff: 0.007; Obj: 11.388; RMSE: 3.363
# Reg-MF: GD - ite: 7; diff: 0.010; Obj: 11.378; RMSE: 3.361
# Reg-MF: GD - ite: 8; diff: 0.022; Obj: 11.356; RMSE: 3.354
# Reg-MF: GD - ite: 9; diff: 0.053; Obj: 11.303; RMSE: 3.336
# Reg-MF: GD - ite: 10; diff: 0.125; Obj: 11.178; RMSE: 3.292
# Reg-MF: GD - ite: 11; diff: 0.251; Obj: 10.927; RMSE: 3.197
# Reg-MF: GD - ite: 12; diff: 0.363; Obj: 10.564; RMSE: 3.037
# Reg-MF: GD - ite: 13; diff: 0.314; Obj: 10.250; RMSE: 2.854
# Reg-MF: GD - ite: 14; diff: 0.161; Obj: 10.089; RMSE: 2.712
# Reg-MF: GD - ite: 15; diff: 0.060; Obj: 10.028; RMSE: 2.625
# Reg-MF: GD - ite: 16; diff: 0.020; Obj: 10.009; RMSE: 2.578
# Reg-MF: GD - ite: 17; diff: 0.006; Obj: 10.002; RMSE: 2.552
# Reg-MF: GD - ite: 18; diff: 0.002; Obj: 10.000; RMSE: 2.539
# Reg-MF: GD - ite: 19; diff: 0.001; Obj: 10.000; RMSE: 2.531
# Reg-MF: GD - ite: 20; diff: 0.000; Obj: 10.000; RMSE: 2.527
# Reg-MF: GD - ite: 21; diff: 0.000; Obj: 10.000; RMSE: 2.525
# 5-Fold CV for K: 1; lam: 0.003162: train_rmse: 2.525112, valid_rmse: 2.714666
# Fitting Reg-MF: K: 1, lam: 0.00316
# Reg-MF: GD - ite: 0; diff: 4.857; Obj: 12.431; RMSE: 3.374
# Reg-MF: GD - ite: 1; diff: 0.632; Obj: 11.799; RMSE: 3.371
# Reg-MF: GD - ite: 2; diff: 0.183; Obj: 11.616; RMSE: 3.366
# Reg-MF: GD - ite: 3; diff: 0.128; Obj: 11.488; RMSE: 3.342
# Reg-MF: GD - ite: 4; diff: 0.205; Obj: 11.284; RMSE: 3.278
# Reg-MF: GD - ite: 5; diff: 0.349; Obj: 10.935; RMSE: 3.147
# Reg-MF: GD - ite: 6; diff: 0.406; Obj: 10.529; RMSE: 2.956
# Reg-MF: GD - ite: 7; diff: 0.271; Obj: 10.258; RMSE: 2.776
# Reg-MF: GD - ite: 8; diff: 0.113; Obj: 10.145; RMSE: 2.655
# Reg-MF: GD - ite: 9; diff: 0.038; Obj: 10.107; RMSE: 2.588
# Reg-MF: GD - ite: 10; diff: 0.012; Obj: 10.096; RMSE: 2.552
# Reg-MF: GD - ite: 11; diff: 0.004; Obj: 10.092; RMSE: 2.534
# Reg-MF: GD - ite: 12; diff: 0.001; Obj: 10.091; RMSE: 2.524
# Reg-MF: GD - ite: 13; diff: 0.000; Obj: 10.091; RMSE: 2.519
# Reg-MF: GD - ite: 14; diff: 0.000; Obj: 10.090; RMSE: 2.516
# Reg-MF: GD - ite: 15; diff: 0.000; Obj: 10.090; RMSE: 2.514
# 5-Fold CV for K: 1; lam: 0.003162: train_rmse: 2.514278, valid_rmse: 2.603740
# Fitting Reg-MF: K: 1, lam: 0.00316
# Reg-MF: GD - ite: 0; diff: 4.826; Obj: 12.320; RMSE: 3.360
# Reg-MF: GD - ite: 1; diff: 0.622; Obj: 11.698; RMSE: 3.362
# Reg-MF: GD - ite: 2; diff: 0.158; Obj: 11.540; RMSE: 3.367
# Reg-MF: GD - ite: 3; diff: 0.059; Obj: 11.481; RMSE: 3.368
# Reg-MF: GD - ite: 4; diff: 0.046; Obj: 11.435; RMSE: 3.361
# Reg-MF: GD - ite: 5; diff: 0.078; Obj: 11.358; RMSE: 3.339
# Reg-MF: GD - ite: 6; diff: 0.163; Obj: 11.194; RMSE: 3.283
# Reg-MF: GD - ite: 7; diff: 0.295; Obj: 10.900; RMSE: 3.170
# Reg-MF: GD - ite: 8; diff: 0.366; Obj: 10.534; RMSE: 2.998
# Reg-MF: GD - ite: 9; diff: 0.275; Obj: 10.258; RMSE: 2.823
# Reg-MF: GD - ite: 10; diff: 0.132; Obj: 10.126; RMSE: 2.694
# Reg-MF: GD - ite: 11; diff: 0.049; Obj: 10.077; RMSE: 2.617
# Reg-MF: GD - ite: 12; diff: 0.016; Obj: 10.061; RMSE: 2.574
# Reg-MF: GD - ite: 13; diff: 0.005; Obj: 10.056; RMSE: 2.552
# Reg-MF: GD - ite: 14; diff: 0.002; Obj: 10.055; RMSE: 2.539
# Reg-MF: GD - ite: 15; diff: 0.001; Obj: 10.054; RMSE: 2.533
# Reg-MF: GD - ite: 16; diff: 0.000; Obj: 10.054; RMSE: 2.529
# Reg-MF: GD - ite: 17; diff: 0.000; Obj: 10.054; RMSE: 2.527
# 5-Fold CV for K: 1; lam: 0.003162: train_rmse: 2.527304, valid_rmse: 2.661462
# Fitting Reg-MF: K: 1, lam: 0.00316
# Reg-MF: GD - ite: 0; diff: 4.992; Obj: 12.265; RMSE: 3.347
# Reg-MF: GD - ite: 1; diff: 0.626; Obj: 11.639; RMSE: 3.348
# Reg-MF: GD - ite: 2; diff: 0.153; Obj: 11.485; RMSE: 3.353
# Reg-MF: GD - ite: 3; diff: 0.050; Obj: 11.436; RMSE: 3.356
# Reg-MF: GD - ite: 4; diff: 0.024; Obj: 11.412; RMSE: 3.357
# Reg-MF: GD - ite: 5; diff: 0.023; Obj: 11.389; RMSE: 3.353
# Reg-MF: GD - ite: 6; diff: 0.042; Obj: 11.347; RMSE: 3.341
# Reg-MF: GD - ite: 7; diff: 0.095; Obj: 11.252; RMSE: 3.310
# Reg-MF: GD - ite: 8; diff: 0.200; Obj: 11.052; RMSE: 3.238
# Reg-MF: GD - ite: 9; diff: 0.334; Obj: 10.717; RMSE: 3.104
# Reg-MF: GD - ite: 10; diff: 0.369; Obj: 10.349; RMSE: 2.923
# Reg-MF: GD - ite: 11; diff: 0.243; Obj: 10.106; RMSE: 2.756
# Reg-MF: GD - ite: 12; diff: 0.104; Obj: 10.002; RMSE: 2.644
# Reg-MF: GD - ite: 13; diff: 0.035; Obj: 9.967; RMSE: 2.581
# Reg-MF: GD - ite: 14; diff: 0.011; Obj: 9.955; RMSE: 2.548
# Reg-MF: GD - ite: 15; diff: 0.003; Obj: 9.952; RMSE: 2.530
# Reg-MF: GD - ite: 16; diff: 0.001; Obj: 9.951; RMSE: 2.520
# Reg-MF: GD - ite: 17; diff: 0.000; Obj: 9.950; RMSE: 2.515
# Reg-MF: GD - ite: 18; diff: 0.000; Obj: 9.950; RMSE: 2.513
# Reg-MF: GD - ite: 19; diff: 0.000; Obj: 9.950; RMSE: 2.511
# 5-Fold CV for K: 1; lam: 0.003162: train_rmse: 2.511010, valid_rmse: 2.750124
# Fitting Reg-MF: K: 1, lam: 0.00316
# Reg-MF: GD - ite: 0; diff: 4.922; Obj: 12.326; RMSE: 3.360
# Reg-MF: GD - ite: 1; diff: 0.649; Obj: 11.677; RMSE: 3.360
# Reg-MF: GD - ite: 2; diff: 0.161; Obj: 11.516; RMSE: 3.364
# Reg-MF: GD - ite: 3; diff: 0.056; Obj: 11.460; RMSE: 3.365
# Reg-MF: GD - ite: 4; diff: 0.037; Obj: 11.424; RMSE: 3.361
# Reg-MF: GD - ite: 5; diff: 0.057; Obj: 11.367; RMSE: 3.346
# Reg-MF: GD - ite: 6; diff: 0.124; Obj: 11.243; RMSE: 3.305
# Reg-MF: GD - ite: 7; diff: 0.251; Obj: 10.992; RMSE: 3.213
# Reg-MF: GD - ite: 8; diff: 0.373; Obj: 10.619; RMSE: 3.053
# Reg-MF: GD - ite: 9; diff: 0.336; Obj: 10.282; RMSE: 2.864
# Reg-MF: GD - ite: 10; diff: 0.178; Obj: 10.104; RMSE: 2.714
# Reg-MF: GD - ite: 11; diff: 0.067; Obj: 10.038; RMSE: 2.622
# Reg-MF: GD - ite: 12; diff: 0.022; Obj: 10.016; RMSE: 2.572
# Reg-MF: GD - ite: 13; diff: 0.007; Obj: 10.009; RMSE: 2.546
# Reg-MF: GD - ite: 14; diff: 0.002; Obj: 10.007; RMSE: 2.532
# Reg-MF: GD - ite: 15; diff: 0.001; Obj: 10.007; RMSE: 2.524
# Reg-MF: GD - ite: 16; diff: 0.000; Obj: 10.006; RMSE: 2.520
# Reg-MF: GD - ite: 17; diff: 0.000; Obj: 10.006; RMSE: 2.518
# 5-Fold CV for K: 1; lam: 0.003162: train_rmse: 2.518172, valid_rmse: 2.694720
# Fitting Reg-MF: K: 1, lam: 0.01000
# Reg-MF: GD - ite: 0; diff: 16.209; Obj: 11.742; RMSE: 3.395
# Reg-MF: GD - ite: 1; diff: 0.183; Obj: 11.559; RMSE: 3.399
# Reg-MF: GD - ite: 2; diff: 0.007; Obj: 11.553; RMSE: 3.399
# Reg-MF: GD - ite: 3; diff: 0.000; Obj: 11.552; RMSE: 3.399
# Reg-MF: GD - ite: 4; diff: 0.000; Obj: 11.552; RMSE: 3.399
# 5-Fold CV for K: 1; lam: 0.010000: train_rmse: 3.398854, valid_rmse: 3.327476
# Fitting Reg-MF: K: 1, lam: 0.01000
# Reg-MF: GD - ite: 0; diff: 16.522; Obj: 11.691; RMSE: 3.385
# Reg-MF: GD - ite: 1; diff: 0.194; Obj: 11.498; RMSE: 3.389
# Reg-MF: GD - ite: 2; diff: 0.007; Obj: 11.491; RMSE: 3.390
# Reg-MF: GD - ite: 3; diff: 0.000; Obj: 11.490; RMSE: 3.390
# Reg-MF: GD - ite: 4; diff: 0.000; Obj: 11.490; RMSE: 3.390
# 5-Fold CV for K: 1; lam: 0.010000: train_rmse: 3.389712, valid_rmse: 3.364562
# Fitting Reg-MF: K: 1, lam: 0.01000
# Reg-MF: GD - ite: 0; diff: 16.029; Obj: 11.495; RMSE: 3.359
# Reg-MF: GD - ite: 1; diff: 0.179; Obj: 11.316; RMSE: 3.363
# Reg-MF: GD - ite: 2; diff: 0.006; Obj: 11.310; RMSE: 3.363
# Reg-MF: GD - ite: 3; diff: 0.000; Obj: 11.309; RMSE: 3.363
# Reg-MF: GD - ite: 4; diff: 0.000; Obj: 11.309; RMSE: 3.363
# 5-Fold CV for K: 1; lam: 0.010000: train_rmse: 3.362928, valid_rmse: 3.470418
# Fitting Reg-MF: K: 1, lam: 0.01000
# Reg-MF: GD - ite: 0; diff: 15.729; Obj: 11.673; RMSE: 3.383
# Reg-MF: GD - ite: 1; diff: 0.192; Obj: 11.481; RMSE: 3.387
# Reg-MF: GD - ite: 2; diff: 0.007; Obj: 11.474; RMSE: 3.387
# Reg-MF: GD - ite: 3; diff: 0.000; Obj: 11.474; RMSE: 3.387
# Reg-MF: GD - ite: 4; diff: 0.000; Obj: 11.474; RMSE: 3.387
# 5-Fold CV for K: 1; lam: 0.010000: train_rmse: 3.387296, valid_rmse: 3.374275
# Fitting Reg-MF: K: 1, lam: 0.01000
# Reg-MF: GD - ite: 0; diff: 15.305; Obj: 11.639; RMSE: 3.381
# Reg-MF: GD - ite: 1; diff: 0.178; Obj: 11.462; RMSE: 3.384
# Reg-MF: GD - ite: 2; diff: 0.006; Obj: 11.456; RMSE: 3.385
# Reg-MF: GD - ite: 3; diff: 0.000; Obj: 11.455; RMSE: 3.385
# Reg-MF: GD - ite: 4; diff: 0.000; Obj: 11.455; RMSE: 3.385
# 5-Fold CV for K: 1; lam: 0.010000: train_rmse: 3.384586, valid_rmse: 3.385135
# Fitting Reg-MF: K: 1, lam: 0.03162
# Reg-MF: GD - ite: 0; diff: 47.117; Obj: 11.565; RMSE: 3.396
# Reg-MF: GD - ite: 1; diff: 0.032; Obj: 11.533; RMSE: 3.396
# Reg-MF: GD - ite: 2; diff: 0.000; Obj: 11.533; RMSE: 3.396
# 5-Fold CV for K: 1; lam: 0.031623: train_rmse: 3.395995, valid_rmse: 3.339132
# Fitting Reg-MF: K: 1, lam: 0.03162
# Reg-MF: GD - ite: 0; diff: 49.456; Obj: 11.321; RMSE: 3.359
# Reg-MF: GD - ite: 1; diff: 0.038; Obj: 11.284; RMSE: 3.359
# Reg-MF: GD - ite: 2; diff: 0.000; Obj: 11.284; RMSE: 3.359
# 5-Fold CV for K: 1; lam: 0.031623: train_rmse: 3.359158, valid_rmse: 3.484949
# Fitting Reg-MF: K: 1, lam: 0.03162
# Reg-MF: GD - ite: 0; diff: 51.463; Obj: 11.501; RMSE: 3.386
# Reg-MF: GD - ite: 1; diff: 0.034; Obj: 11.467; RMSE: 3.386
# Reg-MF: GD - ite: 2; diff: 0.000; Obj: 11.467; RMSE: 3.386
# 5-Fold CV for K: 1; lam: 0.031623: train_rmse: 3.386326, valid_rmse: 3.378169
# Fitting Reg-MF: K: 1, lam: 0.03162
# Reg-MF: GD - ite: 0; diff: 46.656; Obj: 11.438; RMSE: 3.378
# Reg-MF: GD - ite: 1; diff: 0.030; Obj: 11.409; RMSE: 3.378
# Reg-MF: GD - ite: 2; diff: 0.000; Obj: 11.409; RMSE: 3.378
# 5-Fold CV for K: 1; lam: 0.031623: train_rmse: 3.377680, valid_rmse: 3.412624
# Fitting Reg-MF: K: 1, lam: 0.03162
# Reg-MF: GD - ite: 0; diff: 50.897; Obj: 11.620; RMSE: 3.404
# Reg-MF: GD - ite: 1; diff: 0.032; Obj: 11.588; RMSE: 3.404
# Reg-MF: GD - ite: 2; diff: 0.000; Obj: 11.588; RMSE: 3.404
# 5-Fold CV for K: 1; lam: 0.031623: train_rmse: 3.404143, valid_rmse: 3.305750
# Fitting Reg-MF: K: 1, lam: 0.10000
# Reg-MF: GD - ite: 0; diff: -405.366; Obj: 564.310; RMSE: 6.392
# 5-Fold CV for K: 1; lam: 0.100000: train_rmse: 6.392079, valid_rmse: 5.206331
# Fitting Reg-MF: K: 1, lam: 0.10000
# Reg-MF: GD - ite: 0; diff: -671.146; Obj: 842.270; RMSE: 8.323
# 5-Fold CV for K: 1; lam: 0.100000: train_rmse: 8.322647, valid_rmse: 7.278991
# Fitting Reg-MF: K: 1, lam: 0.10000
# Reg-MF: GD - ite: 0; diff: -632.574; Obj: 792.647; RMSE: 7.892
# 5-Fold CV for K: 1; lam: 0.100000: train_rmse: 7.891649, valid_rmse: 7.150915
# Fitting Reg-MF: K: 1, lam: 0.10000
# Reg-MF: GD - ite: 0; diff: -525.002; Obj: 689.281; RMSE: 7.258
# 5-Fold CV for K: 1; lam: 0.100000: train_rmse: 7.258285, valid_rmse: 6.099200
# Fitting Reg-MF: K: 1, lam: 0.10000
# Reg-MF: GD - ite: 0; diff: -620.907; Obj: 786.964; RMSE: 7.877
# 5-Fold CV for K: 1; lam: 0.100000: train_rmse: 7.877001, valid_rmse: 6.866163
# Fitting Reg-MF: K: 1, lam: 0.31623
# Reg-MF: GD - ite: 0; diff: -.000; Obj: .000; RMSE: 364773395100994426098131427628711463687503907267813801106106169496368558646729562954822546746836074111043508447282634038024621512055523465232384.000
# 5-Fold CV for K: 1; lam: 0.316228: train_rmse: 364773395100994426098131427628711463687503907267813801106106169496368558646729562954822546746836074111043508447282634038024621512055523465232384.000000, valid_rmse: 302944441400084281469957467911627481621999659548131554035542998022046212321092616275629017888513881570486194916228713263172415490807175189626880.000000
# Fitting Reg-MF: K: 1, lam: 0.31623
# Reg-MF: GD - ite: 0; diff: -.000; Obj: .000; RMSE: 1054985605951238396680288772954136115231062972549850988442018039906664052658102130302374999562610598690831404694784716826749129476855143312916480.000
# 5-Fold CV for K: 1; lam: 0.316228: train_rmse: 1054985605951238396680288772954136115231062972549850988442018039906664052658102130302374999562610598690831404694784716826749129476855143312916480.000000, valid_rmse: 544665391591523590905925461970009063646935360461185394350031068451134631344429798032533002218376314740744526587603365201254113255444465351393280.000000
# Fitting Reg-MF: K: 1, lam: 0.31623
# Reg-MF: GD - ite: 0; diff: -.000; Obj: .000; RMSE: 433184890025288957324464690948853254252810581207255299447252672086328416517476274068738919311468699565489703529074371452464603318070624477249536.000
# 5-Fold CV for K: 1; lam: 0.316228: train_rmse: 433184890025288957324464690948853254252810581207255299447252672086328416517476274068738919311468699565489703529074371452464603318070624477249536.000000, valid_rmse: 325339367112655798579991555316539553250851110574262195620051316439818235086895487341500536389712445686623383911376549138298454299558943697928192.000000
# Fitting Reg-MF: K: 1, lam: 0.31623
# Reg-MF: GD - ite: 0; diff: -.000; Obj: .000; RMSE: 1296089217869595107983991746220927885417965567012281947717690985927412367441774313430075746348303853086737120862232972195503717978799352456413184.000
# 5-Fold CV for K: 1; lam: 0.316228: train_rmse: 1296089217869595107983991746220927885417965567012281947717690985927412367441774313430075746348303853086737120862232972195503717978799352456413184.000000, valid_rmse: 1092658118894130849458257279992807680316296787772677721198894021157381947350504634790446071280425773119937012875551125288939301022860274592382976.000000
# Fitting Reg-MF: K: 1, lam: 0.31623
# Reg-MF: GD - ite: 0; diff: -.000; Obj: .000; RMSE: 183078778910886916950829390244434944986575032254244678385143360099982675277556438300753118561940858693833515656077578988829110251803185397104640.000
# 5-Fold CV for K: 1; lam: 0.316228: train_rmse: 183078778910886916950829390244434944986575032254244678385143360099982675277556438300753118561940858693833515656077578988829110251803185397104640.000000, valid_rmse: 144865575073473164772147231348736385390960858866085984020571766367984307748404394983095990911120860293188272997444589962095590905827383815700480.000000
# Fitting Reg-MF: K: 1, lam: 1.00000
# /var/folders/j4/qdhvnf5d3wx_4pb2zxl7f9sh0000gn/T/ipykernel_6183/4268937506.py:71: RuntimeWarning: overflow encountered in square
#   return np.sqrt( np.mean( (pred_rating - test_rating)**2) )
# /var/folders/j4/qdhvnf5d3wx_4pb2zxl7f9sh0000gn/T/ipykernel_6183/4268937506.py:66: RuntimeWarning: overflow encountered in square
#   return (self.rmse(test_pair, test_rating))**2 + self.lam*np.sum(self.P**2) + self.lam*np.sum(self.Q**2)
# Reg-MF: GD - ite: 0; diff: -inf; Obj: inf; RMSE: inf
# 5-Fold CV for K: 1; lam: 1.000000: train_rmse: inf, valid_rmse: inf
# Fitting Reg-MF: K: 1, lam: 1.00000
# Reg-MF: GD - ite: 0; diff: -inf; Obj: inf; RMSE: inf
# 5-Fold CV for K: 1; lam: 1.000000: train_rmse: inf, valid_rmse: inf
# Fitting Reg-MF: K: 1, lam: 1.00000
# Reg-MF: GD - ite: 0; diff: -inf; Obj: inf; RMSE: inf
# 5-Fold CV for K: 1; lam: 1.000000: train_rmse: inf, valid_rmse: inf
# Fitting Reg-MF: K: 1, lam: 1.00000
# Reg-MF: GD - ite: 0; diff: -inf; Obj: inf; RMSE: inf
# 5-Fold CV for K: 1; lam: 1.000000: train_rmse: inf, valid_rmse: inf
# Fitting Reg-MF: K: 1, lam: 1.00000
# Reg-MF: GD - ite: 0; diff: -inf; Obj: inf; RMSE: inf
# 5-Fold CV for K: 1; lam: 1.000000: train_rmse: inf, valid_rmse: inf
# Fitting Reg-MF: K: 1, lam: 3.16228
# /var/folders/j4/qdhvnf5d3wx_4pb2zxl7f9sh0000gn/T/ipykernel_6183/4268937506.py:48: RuntimeWarning: overflow encountered in multiply
#   sum_qi = np.sum(self.Q[train_pair_tmp[:,1]] * err_tmp[:,np.newaxis], 0) / n_obs
# /var/folders/j4/qdhvnf5d3wx_4pb2zxl7f9sh0000gn/T/ipykernel_6183/4268937506.py:50: RuntimeWarning: invalid value encountered in add
#   self.P[user_id] = self.P[user_id] + 2*learning_rate*sum_qi - 2*learning_rate*lam*self.P[user_id]
# /Users/simoncheung/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Reg-MF: GD - ite: 0; diff: nan; Obj: nan; RMSE: nan
# /var/folders/j4/qdhvnf5d3wx_4pb2zxl7f9sh0000gn/T/ipykernel_6183/4268937506.py:37: RuntimeWarning: invalid value encountered in add
#   self.Q[item_id] = self.Q[item_id] + 2*learning_rate*sum_pu - 2*learning_rate*lam*self.Q[item_id]
# Reg-MF: GD - ite: 1; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 2; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 3; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 4; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 5; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 6; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 7; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 8; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 9; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 10; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 11; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 12; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 13; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 14; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 15; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 16; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 17; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 18; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 19; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 20; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 21; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 22; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 23; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 24; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 25; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 26; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 27; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 28; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 29; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 30; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 31; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 32; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 33; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 34; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 35; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 36; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 37; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 38; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 39; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 40; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 41; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 42; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 43; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 44; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 45; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 46; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 47; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 48; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 49; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 50; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 51; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 52; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 53; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 54; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 55; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 56; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 57; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 58; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 59; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 60; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 61; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 62; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 63; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 64; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 65; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 66; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 67; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 68; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 69; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 70; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 71; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 72; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 73; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 74; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 75; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 76; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 77; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 78; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 79; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 80; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 81; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 82; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 83; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 84; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 85; diff: nan; Obj: nan; RMSE: nan
# Reg-MF: GD - ite: 86; diff: nan; Obj: nan; RMSE: nan

# %%
## Baseline `glb mean based and item fitted`  + MF
# glb mean
glb_ave = glb_mean()
glb_ave.fit(train_rating)
pred_rating1 = glb_ave.predict(test_pair)

# item_mean
train_rating_cm = train_rating - glb_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred_rating1 = pred_rating + item_ave.predict(test_pair)

#Grid Search
shiing_cv = MF_CV(n_user, n_item, cv=folds, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=MF(n_user, n_item, K=best_K, lam=best_lam, learning_rate=1)
shiing.fit(train_pair, train_rating_res)
pred_rating1 = pred_rating1 + shiing.predict(test_pair)

# %%
## Baseline `user mean based and item based` + MF
# user mean
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred_rating2 = user_ave.predict(test_pair)

# item_mean
train_rating_cm = train_rating - user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred_rating2 = pred_rating2 + item_ave.predict(test_pair)

#Grid Search
shiing_cv = MF_CV(n_user, n_item, cv=folds, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=MF(n_user, n_item, K=best_K, lam=best_lam, learning_rate=1)
shiing.fit(train_pair, train_rating_res)
pred_rating2 = pred_rating2 + shiing.predict(test_pair)

# %%
## Baseline `item mean based and user fitted` + MF
# item mean
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred_rating3 = item_ave.predict(test_pair)

# user_mean
train_rating_cm = train_rating - item_ave.predict(train_pair)
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - user_ave.predict(train_pair)
pred_rating3 = pred_rating3 + user_ave.predict(test_pair)

#Grid Search
shiing_cv = MF_CV(n_user, n_item, cv=folds, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=MF(n_user, n_item, K=best_K, lam=best_lam, learning_rate=1)
shiing.fit(train_pair, train_rating_res)
pred_rating3 = pred_rating3 + shiing.predict(test_pair)

# %%
# submission
sub['rating'] = pred_rating
sub.to_csv('sub1.csv', index=False)
